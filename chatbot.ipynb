# %% [markdown]
# <a href="https://colab.research.google.com/github/suhaodatascichem/chatbot/blob/main/chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies
# !pip install python-docx langchain faiss-cpu sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 21.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 48.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.0 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 60.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# Upload your .docx file
from google.colab import files
uploaded = files.upload()

# Parse .docx content
from docx import Document

def load_docx(file_path):
    doc = Document(file_path)
    full_text = "\n".join([para.text for para in doc.paragraphs if para.text.strip()])
    return full_text

doc_text = load_docx("sop_manufacturing_dummy.docx")
print("Document Loaded:\n", doc_text[:500])  # Preview
# Out:
#      <input type="file" id="files-4ad17b0e-526c-4656-96e9-387c3e0c42db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ad17b0e-526c-4656-96e9-387c3e0c42db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Split into chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=50)
chunks = splitter.split_text(doc_text)
print(f"Number of chunks: {len(chunks)}")

# Embed and create FAISS index
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
db = FAISS.from_texts(chunks, embedding_model)
# Out:
# Number of chunks: 4
# <ipython-input-4-c727bb243e92>:12: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
# !pip install llama-cpp-python

from llama_cpp import Llama

# Download GGUF version of TinyLLaMA from HuggingFace
# !wget https://huggingface.co/TheBloke/TinyLlama-1.1B-Chat-v1.0-GGUF/resolve/main/tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf -O tinyllama.gguf

# Load the model (CPU-only setup)
llm = Llama(model_path="tinyllama.gguf", n_ctx=2048, n_threads=4)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 MB 11.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 4.0 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.3.9-cp311-cp311-linux_x86_64.whl size=4067771 sha256=8284b96bedbdccd0b1f271ef0dc51d0cf89eccbb62c2ee12b1cd9f318a7e1297
#   Stored in directory: /root/.cache/pip/wheels/9e/8f/bf/148c8eb7d69021eccd6eae6444f3accd48347587054ffd24e5
# Successfully built llama-cpp-python
# ...
# --2025-05-17 13:02:58--  https://huggingface.co/TheBloke/TinyLlama-1.1B-Chat-v1.0-GGUF/resolve/main/tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf
# Resolving huggingface.co (huggingface.co)... 3.167.112.96, 3.167.112.25, 3.167.112.45, ...
# Connecting to huggingface.co (huggingface.co)|3.167.112.96|:443... connected.
# ...

# %%
def ask_tinyllama(query):
    # Retrieve relevant chunks
    docs = db.similarity_search(query, k=3)
    context = "\n\n".join([doc.page_content for doc in docs])

    # Use plain prompt — no [INST]
    prompt = f"""Use the following context to answer the question.

Context:
{context}

Question: {query}
Answer:"""


    # Generate answer
    response = llm(prompt, max_tokens=256, stop=["\n\n", "</s>"])
    return response["choices"][0]["text"].strip()

# %%
print(ask_tinyllama('what materials are required for the procedure'))
# Out:
# llama_perf_context_print:        load time =   22781.37 ms
# llama_perf_context_print: prompt eval time =   22780.91 ms /   285 tokens (   79.93 ms per token,    12.51 tokens per second)
# llama_perf_context_print:        eval time =    2423.83 ms /    25 runs   (   96.95 ms per token,    10.31 tokens per second)
# llama_perf_context_print:       total time =   25218.47 ms /   310 tokens
# The materials required for the procedure are a screwdriver, PCB board, screws, and a housing frame.

# %%
print(ask_tinyllama("what torque should be used to fasten the board using 4 screws"))
# Out:
# Llama.generate: 15 prefix-match hit, remaining 280 prompt tokens to eval
# llama_perf_context_print:        load time =   22781.37 ms
# llama_perf_context_print: prompt eval time =   23061.74 ms /   280 tokens (   82.36 ms per token,    12.14 tokens per second)
# llama_perf_context_print:        eval time =    1066.04 ms /    11 runs   (   96.91 ms per token,    10.32 tokens per second)
# llama_perf_context_print:       total time =   24134.62 ms /   291 tokens
# Torque: 0.5 Nm

# %%
print(ask_tinyllama("what button i should use to swtich on the main control"))
# Out:
# Llama.generate: 15 prefix-match hit, remaining 276 prompt tokens to eval
# llama_perf_context_print:        load time =   22781.37 ms
# llama_perf_context_print: prompt eval time =   13361.93 ms /   276 tokens (   48.41 ms per token,    20.66 tokens per second)
# llama_perf_context_print:        eval time =    1253.27 ms /    13 runs   (   96.41 ms per token,    10.37 tokens per second)
# llama_perf_context_print:       total time =   14623.10 ms /   289 tokens
# the red button on the control panel is the power switch.

# %%
print(ask_tinyllama("where should i put pcb board"))
# Out:
# Llama.generate: 15 prefix-match hit, remaining 270 prompt tokens to eval
# llama_perf_context_print:        load time =   22781.37 ms
# llama_perf_context_print: prompt eval time =   13141.38 ms /   270 tokens (   48.67 ms per token,    20.55 tokens per second)
# llama_perf_context_print:        eval time =    2340.90 ms /    24 runs   (   97.54 ms per token,    10.25 tokens per second)
# llama_perf_context_print:       total time =   15495.96 ms /   294 tokens
# put the pcb board on the assembly traing, the direction is based on the power on the main control unit.
